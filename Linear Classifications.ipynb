# %%
source("2-model_tests.R")
# Out:
# Attaching package: 'dplyr'
#
# The following objects are masked from 'package:plyr':
#
#     arrange, count, desc, failwith, id, mutate, rename, summarise,
#     summarize
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union
#
#
# Attaching package: 'tibble'
#
# The following objects are masked from 'package:dplyr':
#
#     as_data_frame, data_frame, data_frame_, frame_data, glimpse,
#     knit_print.trunc_mat, tibble, trunc_mat, type_sum
#
# Loading required package: lattice
# Loading required package: ggplot2
#
# Attaching package: 'purrr'
#
# The following object is masked from 'package:caret':
#
#     lift
#
# The following object is masked from 'package:dplyr':
#
#     order_by
#
# The following object is masked from 'package:plyr':
#
#     compact
#
# Loading required package: Rcpp
# mice 2.25 2015-11-09
# Loading required package: foreach
#
# ...

# %%
mod <- "glm"
prep <- list("nzv", c("nzv", "pca"))
sets <- NULL
set.seed(1056)
mods.glm1 <- run_models(mod, train.dv2i[, -c(1, sets)], valid.dv2i[, -c(1, sets)], prep, trCtrl)
mods.glm1
# Out:
# Warning message:
# In predict.lm(object, newdata, se.fit, scale = 1, type = ifelse(type == : prediction from a rank-deficient fit may be misleading
# $cl
# $glm1
# Generalized Linear Model
#
# 4455 samples
#  329 predictor
#    2 classes: 'Democrat', 'Republican'
#
# Pre-processing: remove (6)
# Resampling: Cross-Validated (10 fold, repeated 5 times)
# Summary of sample sizes: 4010, 4009, 4010, 4010, 4010, 4009, ...
# Resampling results:
#
#   ROC        Sens       Spec
#   0.6553707  0.6425277  0.5640848
#
#
#
# $glm2
# Generalized Linear Model
#
# 4455 samples
#  329 predictor
#    2 classes: 'Democrat', 'Republican'
#
# Pre-processing: principal component signal extraction (323), centered
#  (323), scaled (323), remove (6)
# Resampling: Cross-Validated (10 fold, repeated 5 times)
# Summary of sample sizes: 4010, 4009, 4010, 4010, 4010, 4009, ...
# Resampling results:
#
#   ROC        Sens       Spec
#   0.6635543  0.6572674  0.5606421
#
#
#
# attr(,"class")
# [1] "caretList"
#
# ...

# %%
mod <- "glm"
prep <- list("nzv")
sets <- hc2
set.seed(1056)
mods.glm2 <- run_models(mod, train.dv2i[, -c(1, sets)], valid.dv2i[, -c(1, sets)], prep, trCtrl)
mods.glm2
# Out:
# Loading required package: caretEnsemble
#
# Attaching package: 'caretEnsemble'
#
# The following object is masked from 'package:ggplot2':
#
#     autoplot
# Error in caretList(x = data, y = train.party, metric = "ROC", trControl = ctrl, : object 'glmnGrid' not found
# Traceback:
#
# 1. run_models(mod, train.dv2i[, -c(1, sets)], valid.dv2i[, -c(1,
#  .     sets)], prep, trCtrl, tuneGrid = glmnGrid)
# 2. caretList(x = data, y = train.party, metric = "ROC", trControl = ctrl,
#  .     tuneList = specs, continue_on_fail = TRUE, ...)

# %%
mod <- "glm"
prep <- list("nzv")
sets <- lc$remove
set.seed(1056)
mods.glm3 <- run_models(mod, train.dv2i[, -c(1, sets)], valid.dv2i[, -c(1, sets)], prep, trCtrl)
mods.glm3

# %% [markdown]
# ### Linear Discriminant Analysis

# %%
mod <- "lda"
prep <- list("nzv", c("nzv", "pca"))
sets <- NULL
set.seed(1056)
mods.lda1 <- run_models(mod, train.dv2i[, -c(1, sets)], valid.dv2i[, -c(1, sets)], prep, trCtrl)
mods.lda1
# Out:
# Loading required package: MASS
#
# Attaching package: 'MASS'
#
# The following object is masked from 'package:dplyr':
#
#     select
#
# Warning message:
# In lda.default(x, grouping, ...): variables are collinear
# $cl
# $lda1
# Linear Discriminant Analysis
#
# 4455 samples
#  329 predictor
#    2 classes: 'Democrat', 'Republican'
#
# Pre-processing: remove (6)
# Resampling: Cross-Validated (10 fold, repeated 5 times)
# Summary of sample sizes: 4010, 4009, 4010, 4010, 4010, 4009, ...
# Resampling results:
#
#   ROC        Sens       Spec
#   0.6552747  0.6424426  0.5657102
#
#
#
# $lda2
# Linear Discriminant Analysis
#
# 4455 samples
#  329 predictor
#    2 classes: 'Democrat', 'Republican'
#
# Pre-processing: principal component signal extraction (323), centered
#  (323), scaled (323), remove (6)
# Resampling: Cross-Validated (10 fold, repeated 5 times)
# Summary of sample sizes: 4010, 4009, 4010, 4010, 4010, 4009, ...
# Resampling results:
#
#   ROC        Sens       Spec
# ...

# %%
mod <- "lda"
prep <- list("nzv")
sets <- hc2
set.seed(1056)
mods.lda2 <- run_models(mod, train.dv2i[, -c(1, sets)], valid.dv2i[, -c(1, sets)], prep, trCtrl)
mods.lda2

# %%
mod <- "lda"
prep <- list("nzv")
sets <- lc$remove
set.seed(1056)
mods.lda3 <- run_models(mod, train.dv2i[, -c(1, sets)], valid.dv2i[, -c(1, sets)], prep, trCtrl)
mods.lda3

# %% [markdown]
# ### Partial Least Squares Discriminant Analysis

# %%
mod <- "pls"
prep <- list("nzv")
sets <- NULL
set.seed(1056)
mods.pls1 <- run_models(mod, train.dv2i[, -c(1, sets)], valid.dv2i[, -c(1, sets)], prep, trCtrl, 
                        tuneGrid = expand.grid(.ncomp = 1:10))
mods.pls1
# Out:
# $cl
# $pls1
# Partial Least Squares
#
# 4455 samples
#  329 predictor
#    2 classes: 'Democrat', 'Republican'
#
# Pre-processing: remove (6)
# Resampling: Cross-Validated (10 fold, repeated 5 times)
# Summary of sample sizes: 4010, 4009, 4010, 4010, 4010, 4009, ...
# Resampling results across tuning parameters:
#
#   ncomp  ROC        Sens       Spec
#    1     0.5261136  0.9704466  0.04417134
#    2     0.6054663  0.6972456  0.46656414
#    3     0.6667711  0.6820865  0.55214901
#    4     0.6735500  0.6886866  0.55272864
#    5     0.6716672  0.6748863  0.55664434
#    6     0.6655636  0.6589645  0.55978811
#    7     0.6610192  0.6537134  0.55729779
#    8     0.6583918  0.6421054  0.56140488
#    9     0.6576287  0.6413420  0.55969105
#   10     0.6555574  0.6409186  0.55815676
#
# ROC was used to select the optimal model using  the largest value.
# The final value used for the model was ncomp = 4.
#
# attr(,"class")
# [1] "caretList"
#
# $cm
# $cm$pls1
# ...

# %%
mod <- "pls"
prep <- list("nzv")
sets <- hc2
set.seed(1056)
mods.pls2 <- run_models(mod, train.dv2i[, -c(1, sets)], valid.dv2i[, -c(1, sets)], prep, trCtrl, 
                        tuneGrid = expand.grid(.ncomp = 1:10))
mods.pls2
# Out:
# $cl
# $pls1
# Partial Least Squares
#
# 4455 samples
#  315 predictor
#    2 classes: 'Democrat', 'Republican'
#
# Pre-processing: remove (6)
# Resampling: Cross-Validated (10 fold, repeated 5 times)
# Summary of sample sizes: 4010, 4009, 4010, 4010, 4010, 4009, ...
# Resampling results across tuning parameters:
#
#   ncomp  ROC        Sens       Spec
#    1     0.5268822  0.9757831  0.03911506
#    2     0.6088944  0.6997865  0.46895329
#    3     0.6691372  0.6866663  0.54814946
#    4     0.6748003  0.6908939  0.55015038
#    5     0.6712970  0.6742927  0.55808248
#    6     0.6656756  0.6559111  0.56198496
#    7     0.6616236  0.6534563  0.55740032
#    8     0.6590725  0.6416820  0.56255730
#    9     0.6581907  0.6428667  0.56245477
#   10     0.6564563  0.6431231  0.55940852
#
# ROC was used to select the optimal model using  the largest value.
# The final value used for the model was ncomp = 4.
#
# attr(,"class")
# [1] "caretList"
#
# $cm
# $cm$pls1
# ...

# %%
mod <- "pls"
prep <- list("nzv")
sets <- lc$remove
set.seed(1056)
mods.pls3 <- run_models(mod, train.dv2i[, -c(1, sets)], valid.dv2i[, -c(1, sets)], prep, trCtrl, 
                        tuneGrid = expand.grid(.ncomp = 1:10))
mods.pls3
# Out:
# $cl
# $pls1
# Partial Least Squares
#
# 4455 samples
#  225 predictor
#    2 classes: 'Democrat', 'Republican'
#
# Pre-processing: remove (5)
# Resampling: Cross-Validated (10 fold, repeated 5 times)
# Summary of sample sizes: 4010, 4009, 4010, 4010, 4010, 4009, ...
# Resampling results across tuning parameters:
#
#   ncomp  ROC        Sens       Spec
#    1     0.5262288  0.9829833  0.02785874
#    2     0.6385339  0.7265572  0.46962497
#    3     0.6729033  0.6843760  0.55998952
#    4     0.6755675  0.6845387  0.55520802
#    5     0.6676456  0.6648881  0.55892732
#    6     0.6672012  0.6585357  0.56130827
#    7     0.6632507  0.6523561  0.56092504
#    8     0.6621395  0.6533709  0.56112281
#    9     0.6574025  0.6460906  0.55969332
#   10     0.6553027  0.6444779  0.55463203
#
# ROC was used to select the optimal model using  the largest value.
# The final value used for the model was ncomp = 4.
#
# attr(,"class")
# [1] "caretList"
#
# $cm
# $cm$pls1
# ...

# %% [markdown]
# ### Penalized Models

# %%
glmnGrid <- expand.grid(.alpha = c(0, 0.1, 0.2, 0.4, 0.6, 0.8, 1), .lambda = seq(0.1, 0.2, length = 40))

# %%
mod <- "glmnet"
prep <- list(c("nzv"))
sets <- NULL
set.seed(1056)
mods.glmnet1 <- run_models(mod, train.dv2i[, -c(1, sets)], valid.dv2i[, -c(1, sets)], prep, trCtrl, tuneGrid = glmnGrid)
mods.glmnet1
# Out:
# Loading required package: glmnet
# Loading required package: Matrix
# Loaded glmnet 2.0-5
# $cl
# $glmnet1
# glmnet
#
# 4455 samples
#  329 predictor
#    2 classes: 'Democrat', 'Republican'
#
# Pre-processing: remove (6)
# Resampling: Cross-Validated (10 fold, repeated 5 times)
# Summary of sample sizes: 4010, 4009, 4010, 4010, 4010, 4009, ...
# Resampling results across tuning parameters:
#
#   alpha  lambda     ROC        Sens       Spec
#   0.0    0.1000000  0.6692140  0.6809011  0.544030075
#   0.0    0.1025641  0.6693803  0.6814936  0.544029164
#   0.0    0.1051282  0.6695318  0.6820003  0.543169743
#   0.0    0.1076923  0.6696556  0.6833551  0.543169287
#   0.0    0.1102564  0.6697713  0.6840331  0.542692185
#   0.0    0.1128205  0.6699186  0.6847955  0.542406471
#   0.0    0.1153846  0.6700585  0.6852188  0.542407838
#   0.0    0.1179487  0.6701702  0.6859805  0.541740260
#   0.0    0.1205128  0.6702920  0.6868272  0.541452723
# ...

# %%
mod <- "glmnet"
prep <- list(c("nzv"))
sets <- hc2
set.seed(1056)
mods.glmnet2 <- run_models(mod, train.dv2i[, -c(1, sets)], valid.dv2i[, -c(1, sets)], prep, trCtrl, tuneGrid = glmnGrid)
mods.glmnet2
# Out:
# $cl
# $glmnet1
# glmnet
#
# 4455 samples
#  315 predictor
#    2 classes: 'Democrat', 'Republican'
#
# Pre-processing: remove (6)
# Resampling: Cross-Validated (10 fold, repeated 5 times)
# Summary of sample sizes: 4010, 4009, 4010, 4010, 4010, 4009, ...
# Resampling results across tuning parameters:
#
#   alpha  lambda     ROC        Sens       Spec
#   0.0    0.1000000  0.6696519  0.6824265  0.544409661
#   0.0    0.1025641  0.6697996  0.6832729  0.543645933
#   0.0    0.1051282  0.6699586  0.6846288  0.543073137
#   0.0    0.1076923  0.6701153  0.6859837  0.542501253
#   0.0    0.1102564  0.6702200  0.6864915  0.542406015
#   0.0    0.1128205  0.6703714  0.6870843  0.542215539
#   0.0    0.1153846  0.6704989  0.6875928  0.541261335
#   0.0    0.1179487  0.6705819  0.6878474  0.540879471
#   0.0    0.1205128  0.6706883  0.6881864  0.540497152
#   0.0    0.1230769  0.6708072  0.6888640  0.540497608
#   0.0    0.1256410  0.6709072  0.6892877  0.540019139
# ...

# %%
mod <- "glmnet"
prep <- list(c("nzv"))
sets <- lc$remove
set.seed(1056)
mods.glmnet3 <- run_models(mod, train.dv2i[, -c(1, sets)], valid.dv2i[, -c(1, sets)], prep, trCtrl, tuneGrid = glmnGrid)
mods.glmnet3

# %% [markdown]
# ### Nearest Shrunken Centroids

# %%
nscGrid <- data.frame(.threshold = 0:25)

# %%
mod <- "pam"
prep <- list(c("nzv"))
sets <- NULL
set.seed(1056)
mods.nsc1 <- run_models(mod, train.dv2i[, -c(1, sets)], valid.dv2i[, -c(1, sets)], prep, trCtrl, tuneGrid = nscGrid)
mods.nsc1
# Out:
# Loading required package: pamr
# Loading required package: cluster
# Loading required package: survival
#
# Attaching package: 'survival'
#
# The following object is masked from 'package:caret':
#
#     cluster
# 1
# $cl
# $pam1
# Nearest Shrunken Centroids
#
# 4455 samples
#  329 predictor
#    2 classes: 'Democrat', 'Republican'
#
# Pre-processing: remove (6)
# Resampling: Cross-Validated (10 fold, repeated 5 times)
# Summary of sample sizes: 4010, 4009, 4010, 4010, 4010, 4009, ...
# Resampling results across tuning parameters:
#
#   threshold  ROC        Sens       Spec
#    0         0.6084583  0.6702213  0.4945505
#    1         0.6753312  0.7954234  0.4140292
#    2         0.6783439  0.8400622  0.3488927
#    3         0.6710966  0.9204527  0.1912381
#    4         0.6551092  1.0000000  0.0000000
#    5         0.6184938  1.0000000  0.0000000
#    6         0.6181001  1.0000000  0.0000000
#    7         0.4885879  1.0000000  0.0000000
# ...

# %%
mod <- "pam"
prep <- list(c("nzv"))
sets <- hc2
set.seed(1056)
mods.nsc2 <- run_models(mod, train.dv2i[, -c(1, sets)], valid.dv2i[, -c(1, sets)], prep, trCtrl, tuneGrid = nscGrid)
mods.nsc2
# Out:
# 1
# $cl
# $pam1
# Nearest Shrunken Centroids
#
# 4455 samples
#  315 predictor
#    2 classes: 'Democrat', 'Republican'
#
# Pre-processing: remove (6)
# Resampling: Cross-Validated (10 fold, repeated 5 times)
# Summary of sample sizes: 4010, 4009, 4010, 4010, 4010, 4009, ...
# Resampling results across tuning parameters:
#
#   threshold  ROC        Sens       Spec
#    0         0.6130700  0.6819112  0.4893990
#    1         0.6764080  0.8049113  0.4065860
#    2         0.6774654  0.8371830  0.3601741
#    3         0.6708360  0.9239269  0.1824557
#    4         0.6551092  1.0000000  0.0000000
#    5         0.6184938  1.0000000  0.0000000
#    6         0.6181001  1.0000000  0.0000000
#    7         0.4856612  1.0000000  0.0000000
#    8         0.5000000  1.0000000  0.0000000
#    9         0.5000000  1.0000000  0.0000000
#   10         0.5000000  1.0000000  0.0000000
#   11         0.5000000  1.0000000  0.0000000
#   12         0.5000000  1.0000000  0.0000000
# ...

# %%
mod <- "pam"
prep <- list(c("nzv"))
sets <- lc$remove
set.seed(1056)
mods.nsc3 <- run_models(mod, train.dv2i[, -c(1, sets)], valid.dv2i[, -c(1, sets)], prep, trCtrl, tuneGrid = nscGrid)
mods.nsc3
# Out:
# 1
# $cl
# $pam1
# Nearest Shrunken Centroids
#
# 4455 samples
#  225 predictor
#    2 classes: 'Democrat', 'Republican'
#
# Pre-processing: remove (5)
# Resampling: Cross-Validated (10 fold, repeated 5 times)
# Summary of sample sizes: 4010, 4009, 4010, 4010, 4010, 4009, ...
# Resampling results across tuning parameters:
#
#   threshold  ROC        Sens       Spec
#    0         0.6435083  0.7325713  0.4686758
#    1         0.6754489  0.7943213  0.4182338
#    2         0.6789888  0.8350658  0.3594965
#    3         0.6718595  0.9085082  0.2163454
#    4         0.6560249  1.0000000  0.0000000
#    5         0.6190050  1.0000000  0.0000000
#    6         0.6181001  1.0000000  0.0000000
#    7         0.4728530  1.0000000  0.0000000
#    8         0.5000000  1.0000000  0.0000000
#    9         0.5000000  1.0000000  0.0000000
#   10         0.5000000  1.0000000  0.0000000
#   11         0.5000000  1.0000000  0.0000000
#   12         0.5000000  1.0000000  0.0000000
# ...

# %% [markdown]
# #### Prior Best Fits

# %%
#set.seed(1056)
#glm3 <- train(x = train.hc[, -1], y = train.party, method = "glm", trControl = trCtrl, metric = "ROC",
#              preProcess = c("nzv", "knnImpute"))

# %%
#set.seed(1056)
#pls2 <- train(x = train.hc2[, -1], y = train.party, method = "pls", trControl = trCtrl, metric = "ROC",
#              preProcess = c("nzv", "knnImpute"), tuneGrid = expand.grid(.ncomp = 1:10))

# %% [markdown]
# ### Model Comparison

# %%
model_list1 <- c(mods.glm1$cl, mods.lda1$cl, mods.pls1$cl, mods.glmnet1$cl, mods.nsc1$cl)

# %%
modelCor(resamples(model_list1))
